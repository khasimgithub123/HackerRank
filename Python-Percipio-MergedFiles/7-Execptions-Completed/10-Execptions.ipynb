# %% [markdown]
# # Exceptions

# %% [markdown]
# * An exception is an error that happens during execution of a program. When that
# error occurs, Python generate an exception that can be handled, which avoids your
# program to crash.<br><br>
# * Python has many built-in exceptions which forces your program to output an error when something in it goes wrong.<br><br>
# * When you think that you have a code which can produce an error then
# you can use exception handling.<br><br>

# %% [markdown]
# * The `try` block lets you test a block of code for errors.

# %% [markdown]
# * The `except` block lets you handle the error.

# %% [markdown]
# * The `finally` block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# ![Screenshot%202019-08-06%20at%206.51.33%20PM.png](attachment:Screenshot%202019-08-06%20at%206.51.33%20PM.png)
# ![Screenshot%202019-08-06%20at%206.52.18%20PM.png](attachment:Screenshot%202019-08-06%20at%206.52.18%20PM.png)

# %% [markdown]
# ## <br><br>Exception Handling

# %% [markdown]
# ## <br>`try` block

# %% [markdown]
# ### The `try` block lets you test a block of code for errors.

# %% [markdown]
# #### <br><br>Example 1

# %%
print(variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-503d059fc525> in <module>
# ----> 1 print(variable)
#
# NameError: name 'variable' is not defined

# %%
try:
    print(variable)
    
except:
    print("Exception occurred(Name Error), because 'variable' was not defined ")
# Out:
# Exception occurred(Name Error), because 'variable' was not defined

# %%
try:
    print(variable)
    
except NameError:
    print("Variable  is not defined")
    
except:
    print("An unknown error has occurred")
# Out:
# Variable  is not defined

# %% [markdown]
# #### <br><br>Example 2

# %%
f = open('nonexistent_file')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-03fb5d55533c> in <module>
# ----> 1 f = open('nonexistent_file')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistent_file'

# %%
try:
    f = open('nonexistent_file') 
    
except FileNotFoundError: 
    print('No such file')
    
except:
    print('An unknown error has occurred')
# Out:
# No such file

# %% [markdown]
# #### <br><br>Example 3
# Enter a string such as "python". This will throw a ValueError exception

# %%
input_var = int(input("Please enter a number:  "))
# Out:
# Please enter a number:  python
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-7ebda6fe1e7d> in <module>
# ----> 1 input_var = int(input("Please enter a number:  "))
#
# ValueError: invalid literal for int() with base 10: 'python'

# %% [markdown]
# #### Enter different strings and then a number
# This will keep throwing a ValueError until a number has been input.

# %%
while True:
    try:
        input_var = int(input("Please enter a number: "))
        break
    except ValueError:
        print("Oops!  That was not a valid number. Try again...")
# Out:
# Please enter a number: python
# Oops!  That was not a valid number. Try again...
# Please enter a number: cobra
# Oops!  That was not a valid number. Try again...
# Please enter a number: 37

# %% [markdown]
# #### It is up to you how you handle an exception
# Here, an exception is thrown the first two times a user enters a non-numeric value. Then on the third attempt we process the input as a string

# %%
attempts = 0

while True:
    
    try:
        input_var = input("Please enter a number: ")
        input_var = int(input_var)
        break
        
    except ValueError:
        attempts += 1
        
        if attempts < 3:
            print("Oops!  That was not a valid number. Try again...")
        else:
            print("You really want to input a string! Fine we'll handle it")
            input_var = str(input_var)
            break
# Out:
# Please enter a number: python
# Oops!  That was not a valid number. Try again...
# Please enter a number: cobra
# Oops!  That was not a valid number. Try again...
# Please enter a number: viper
# You really want to input a string! Fine we'll handle it

# %% [markdown]
# #### A KeyboardInterrupt can also be caught and handled
# Unless you'd rather wait for 111 seconds, hit the "Stop" button on the Jupyter Notebook to halt the sleep. That will trigger a keyboard interrupt and can be caught and handled

# %%
import time

time.sleep(111)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-24aead4d7aab> in <module>
#       1 import time
#       2
# ----> 3 time.sleep(111)
#
# KeyboardInterrupt:

# %%
try:
    time.sleep(111)
    
except KeyboardInterrupt:
    print ("KeyboardInterrupt has occurred!")
# Out:
# KeyboardInterrupt has occurred!

# %%
f = open('nonexistent_file')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-03fb5d55533c> in <module>
# ----> 1 f = open('nonexistent_file')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistent_file'

# %% [markdown]
# #### There is an exception hierarchy in Python
# FileNotFoundError is a subclass of OSError

# %%
try: 
    f = open('nonexistent_file') 
except OSError: 
        print('OS Error') 
except FileNotFoundError: 
        print('File not found Error')
# Out:
# OS Error

# %%
try: 
    f = open('nonexistent_file') 
except FileNotFoundError: 
        print('File not found Error') 
except OSError: 
        print('OS Error')
# Out:
# File not found Error

# %% [markdown]
# ## <br><br>`finally` block

# %% [markdown]
# ### The `finally` block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# #### <br><br>Example 1

# %%
print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2ea387ab95ff> in <module>
# ----> 1 print(var)
#
# NameError: name 'var' is not defined

# %%
try:
    print(var)
    
except NameError:
    print("The variable has not been defined")
    
finally:
    print("The 'try except block' ended")
# Out:
# The variable has not been defined
# The 'try except block' ended

# %%
var = 'xyz'

try:
    print(var)
    
except NameError:
    print("The variable has not been defined")
    
finally:
    print("The 'try except block' ended")
# Out:
# xyz
# The 'try except block' ended

# %% [markdown]
# #### <br><br>Example 2

# %%
try:
    file = open("testfile.txt", "w")
    
finally:
    print ("Done with processing the file.")
# Out:
# Done with processing the file.

# %%
ls
# Out:
# 1.FileOperationsTextFile.ipynb*   5.Exceptions .ipynb*
# 2.FileOperationsJSON.ipynb*       Demo6-PythonFromCommandLine_*
# 3.FileOperationsCSV.ipynb*        data_file/
# 4.FileOperationsHTMLFile  .ipynb* testfile.txt

# %%
file.closed
# Out:
# False

# %% [markdown]
# #### <br><br>Example 3

# %% [markdown]
# * Here using `try` and `finally`  we can open and close the file named `testfile.txt`

# %%
try:
    file = open("testfile.txt")
    
finally:
    file.close()
    print ("Done with processing the file.")
# Out:
# Done with processing the file.

# %%
file.closed
# Out:
# True

# %% [markdown]
# ## <br><br> `else`

# %% [markdown]
# ### We can use the `else` keyword to define a block of code to be executed if no errors were raised:

# %% [markdown]
# #### <br><br>Example 1

# %%
try:
    file = open("testfile.txt")
    file.write("Writing to the open file")
    
except:
    print("Oops! Something went wrong")
    
else:
    print("Nothing went wrong")
# Out:
# Oops! Something went wrong

# %%
try:
    file = open("testfile.txt", "w")
    file.write("Writing to the open file")
    print("One line written to the file")
    
except:
    print("Oops! Something went wrong")
    
else:
    print("Nothing went wrong")
# Out:
# One line written to the file
# Nothing went wrong

# %% [markdown]
# #### <br><br>Example 4

# %%
a = int(5)

b = str('Hello')

d = a + b + c

d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-107a7c54a784> in <module>
#       3 b = str('Hello')
#       4
# ----> 5 d = a + b + c
#       6
#       7 d
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #### Handle the TypeError

# %%
try: 
    
    a = int(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
# Out:
# TypeError was thrown

# %% [markdown]
# #### Fix the error
# This time a NameError is thrown and is not handled

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-1a061faa8c32> in <module>
#       3     a = str(5)
#       4     b = str('Hello')
# ----> 5     d = a + b + c
#       6
#       7 except TypeError:
#
# NameError: name 'c' is not defined

# %% [markdown]
# #### Handle the NameError

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print("NameError was thrown")
# Out:
# NameError was thrown

# %% [markdown]
# #### Fix the NameError
# A ValueError is thrown this time

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = int(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print('NameError was thrown')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-7ba832be9aa9> in <module>
#       3     a = str(5)
#       4     b = str('Hello')
# ----> 5     c = int(' World')
#       6     d = a + b + c
#       7
#
# ValueError: invalid literal for int() with base 10: ' World'

# %% [markdown]
# #### Handle the ValueError

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = int(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print('NameError was thrown')
    
except ValueError:
    print('ValueError was thrown')
# Out:
# ValueError was thrown

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = str(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print("NameError was thrown")
    
except ValueError:
    print('ValueError was thrown')    
    
except:
    print('An unknown error was thrown')

# %% [markdown]
# ## <br>Raising an Exception

# %% [markdown]
# #### Example1
# Define the conditions under which you would like to raise an exception

# %%
number = int(input("Enter a number:"))

if number > 5:
    raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))
# Out:
# Enter a number:34
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-34-d5abcb37332d> in <module>
#       2
#       3 if number > 5:
# ----> 4     raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))
#
# Exception: The number should not exceed 5. The value of number is: 34

# %% [markdown]
# #### Example 2
# Handle exceptions which you raise

# %%
number = int(input("Enter a number:"))

try:
    if number > 5:
        raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))

except Exception as error:
    print('Caught this Error: ' + repr(error))
# Out:
# Enter a number:36
# Caught this Error: Exception('The number should not exceed 5. The value of number is: 36')

# %% [markdown]
# # Exceptions

# %% [markdown]
# * An exception is an error that happens during execution of a program. When that
# error occurs, Python generate an exception that can be handled, which avoids your
# program to crash.<br><br>
# * Python has many built-in exceptions which forces your program to output an error when something in it goes wrong.<br><br>
# * When you think that you have a code which can produce an error then
# you can use exception handling.<br><br>

# %% [markdown]
# * The `try` block lets you test a block of code for errors.

# %% [markdown]
# * The `except` block lets you handle the error.

# %% [markdown]
# * The `finally` block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# ![Screenshot%202019-08-06%20at%206.51.33%20PM.png](attachment:Screenshot%202019-08-06%20at%206.51.33%20PM.png)
# ![Screenshot%202019-08-06%20at%206.52.18%20PM.png](attachment:Screenshot%202019-08-06%20at%206.52.18%20PM.png)

# %% [markdown]
# ## <br><br>Exception Handling

# %% [markdown]
# ## <br>`try` block

# %% [markdown]
# ### The `try` block lets you test a block of code for errors.

# %% [markdown]
# #### <br><br>Example 1

# %%
print(variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-503d059fc525> in <module>
# ----> 1 print(variable)
#
# NameError: name 'variable' is not defined

# %%
try:
    print(variable)
    
except:
    print("Exception occurred(Name Error), because 'variable' was not defined ")
# Out:
# Exception occurred(Name Error), because 'variable' was not defined

# %%
try:
    print(variable)
    
except NameError:
    print("Variable  is not defined")
    
except:
    print("An unknown error has occurred")
# Out:
# Variable  is not defined

# %% [markdown]
# #### <br><br>Example 2

# %%
f = open('nonexistent_file')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-03fb5d55533c> in <module>
# ----> 1 f = open('nonexistent_file')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistent_file'

# %%
try:
    f = open('nonexistent_file') 
    
except FileNotFoundError: 
    print('No such file')
    
except:
    print('An unknown error has occurred')
# Out:
# No such file

# %% [markdown]
# #### <br><br>Example 3
# Enter a string such as "python". This will throw a ValueError exception

# %%
input_var = int(input("Please enter a number:  "))
# Out:
# Please enter a number:  python
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-7ebda6fe1e7d> in <module>
# ----> 1 input_var = int(input("Please enter a number:  "))
#
# ValueError: invalid literal for int() with base 10: 'python'

# %% [markdown]
# #### Enter different strings and then a number
# This will keep throwing a ValueError until a number has been input.

# %%
while True:
    try:
        input_var = int(input("Please enter a number: "))
        break
    except ValueError:
        print("Oops!  That was not a valid number. Try again...")
# Out:
# Please enter a number: python
# Oops!  That was not a valid number. Try again...
# Please enter a number: cobra
# Oops!  That was not a valid number. Try again...
# Please enter a number: 37

# %% [markdown]
# #### It is up to you how you handle an exception
# Here, an exception is thrown the first two times a user enters a non-numeric value. Then on the third attempt we process the input as a string

# %%
attempts = 0

while True:
    
    try:
        input_var = input("Please enter a number: ")
        input_var = int(input_var)
        break
        
    except ValueError:
        attempts += 1
        
        if attempts < 3:
            print("Oops!  That was not a valid number. Try again...")
        else:
            print("You really want to input a string! Fine we'll handle it")
            input_var = str(input_var)
            break
# Out:
# Please enter a number: python
# Oops!  That was not a valid number. Try again...
# Please enter a number: cobra
# Oops!  That was not a valid number. Try again...
# Please enter a number: viper
# You really want to input a string! Fine we'll handle it

# %% [markdown]
# #### A KeyboardInterrupt can also be caught and handled
# Unless you'd rather wait for 111 seconds, hit the "Stop" button on the Jupyter Notebook to halt the sleep. That will trigger a keyboard interrupt and can be caught and handled

# %%
import time

time.sleep(111)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-24aead4d7aab> in <module>
#       1 import time
#       2
# ----> 3 time.sleep(111)
#
# KeyboardInterrupt:

# %%
try:
    time.sleep(111)
    
except KeyboardInterrupt:
    print ("KeyboardInterrupt has occurred!")
# Out:
# KeyboardInterrupt has occurred!

# %%
f = open('nonexistent_file')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-03fb5d55533c> in <module>
# ----> 1 f = open('nonexistent_file')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistent_file'

# %% [markdown]
# #### There is an exception hierarchy in Python
# FileNotFoundError is a subclass of OSError

# %%
try: 
    f = open('nonexistent_file') 
except OSError: 
        print('OS Error') 
except FileNotFoundError: 
        print('File not found Error')
# Out:
# OS Error

# %%
try: 
    f = open('nonexistent_file') 
except FileNotFoundError: 
        print('File not found Error') 
except OSError: 
        print('OS Error')
# Out:
# File not found Error

# %% [markdown]
# ## <br><br>`finally` block

# %% [markdown]
# ### The `finally` block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# #### <br><br>Example 1

# %%
print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2ea387ab95ff> in <module>
# ----> 1 print(var)
#
# NameError: name 'var' is not defined

# %%
try:
    print(var)
    
except NameError:
    print("The variable has not been defined")
    
finally:
    print("The 'try except block' ended")
# Out:
# The variable has not been defined
# The 'try except block' ended

# %%
var = 'xyz'

try:
    print(var)
    
except NameError:
    print("The variable has not been defined")
    
finally:
    print("The 'try except block' ended")
# Out:
# xyz
# The 'try except block' ended

# %% [markdown]
# #### <br><br>Example 2

# %%
try:
    file = open("testfile.txt", "w")
    
finally:
    print ("Done with processing the file.")
# Out:
# Done with processing the file.

# %%
ls
# Out:
# 1.FileOperationsTextFile.ipynb*   5.Exceptions .ipynb*
# 2.FileOperationsJSON.ipynb*       Demo6-PythonFromCommandLine_*
# 3.FileOperationsCSV.ipynb*        data_file/
# 4.FileOperationsHTMLFile  .ipynb* testfile.txt

# %%
file.closed
# Out:
# False

# %% [markdown]
# #### <br><br>Example 3

# %% [markdown]
# * Here using `try` and `finally`  we can open and close the file named `testfile.txt`

# %%
try:
    file = open("testfile.txt")
    
finally:
    file.close()
    print ("Done with processing the file.")
# Out:
# Done with processing the file.

# %%
file.closed
# Out:
# True

# %% [markdown]
# ## <br><br> `else`

# %% [markdown]
# ### We can use the `else` keyword to define a block of code to be executed if no errors were raised:

# %% [markdown]
# #### <br><br>Example 1

# %%
try:
    file = open("testfile.txt")
    file.write("Writing to the open file")
    
except:
    print("Oops! Something went wrong")
    
else:
    print("Nothing went wrong")
# Out:
# Oops! Something went wrong

# %%
try:
    file = open("testfile.txt", "w")
    file.write("Writing to the open file")
    print("One line written to the file")
    
except:
    print("Oops! Something went wrong")
    
else:
    print("Nothing went wrong")
# Out:
# One line written to the file
# Nothing went wrong

# %% [markdown]
# #### <br><br>Example 4

# %%
a = int(5)

b = str('Hello')

d = a + b + c

d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-107a7c54a784> in <module>
#       3 b = str('Hello')
#       4
# ----> 5 d = a + b + c
#       6
#       7 d
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #### Handle the TypeError

# %%
try: 
    
    a = int(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
# Out:
# TypeError was thrown

# %% [markdown]
# #### Fix the error
# This time a NameError is thrown and is not handled

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-1a061faa8c32> in <module>
#       3     a = str(5)
#       4     b = str('Hello')
# ----> 5     d = a + b + c
#       6
#       7 except TypeError:
#
# NameError: name 'c' is not defined

# %% [markdown]
# #### Handle the NameError

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print("NameError was thrown")
# Out:
# NameError was thrown

# %% [markdown]
# #### Fix the NameError
# A ValueError is thrown this time

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = int(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print('NameError was thrown')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-7ba832be9aa9> in <module>
#       3     a = str(5)
#       4     b = str('Hello')
# ----> 5     c = int(' World')
#       6     d = a + b + c
#       7
#
# ValueError: invalid literal for int() with base 10: ' World'

# %% [markdown]
# #### Handle the ValueError

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = int(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print('NameError was thrown')
    
except ValueError:
    print('ValueError was thrown')
# Out:
# ValueError was thrown

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = str(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print("NameError was thrown")
    
except ValueError:
    print('ValueError was thrown')    
    
except:
    print('An unknown error was thrown')

# %% [markdown]
# ## <br>Raising an Exception

# %% [markdown]
# #### Example1
# Define the conditions under which you would like to raise an exception

# %%
number = int(input("Enter a number:"))

if number > 5:
    raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))
# Out:
# Enter a number:34
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-34-d5abcb37332d> in <module>
#       2
#       3 if number > 5:
# ----> 4     raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))
#
# Exception: The number should not exceed 5. The value of number is: 34

# %% [markdown]
# #### Example 2
# Handle exceptions which you raise

# %%
number = int(input("Enter a number:"))

try:
    if number > 5:
        raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))

except Exception as error:
    print('Caught this Error: ' + repr(error))
# Out:
# Enter a number:36
# Caught this Error: Exception('The number should not exceed 5. The value of number is: 36')

# %% [markdown]
# # Exceptions

# %% [markdown]
# * An exception is an error that happens during execution of a program. When that
# error occurs, Python generate an exception that can be handled, which avoids your
# program to crash.<br><br>
# * Python has many built-in exceptions which forces your program to output an error when something in it goes wrong.<br><br>
# * When you think that you have a code which can produce an error then
# you can use exception handling.<br><br>

# %% [markdown]
# * The `try` block lets you test a block of code for errors.

# %% [markdown]
# * The `except` block lets you handle the error.

# %% [markdown]
# * The `finally` block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# ![Screenshot%202019-08-06%20at%206.51.33%20PM.png](attachment:Screenshot%202019-08-06%20at%206.51.33%20PM.png)
# ![Screenshot%202019-08-06%20at%206.52.18%20PM.png](attachment:Screenshot%202019-08-06%20at%206.52.18%20PM.png)

# %% [markdown]
# ## <br><br>Exception Handling

# %% [markdown]
# ## <br>`try` block

# %% [markdown]
# ### The `try` block lets you test a block of code for errors.

# %% [markdown]
# #### <br><br>Example 1

# %%
print(variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-503d059fc525> in <module>
# ----> 1 print(variable)
#
# NameError: name 'variable' is not defined

# %%
try:
    print(variable)
    
except:
    print("Exception occurred(Name Error), because 'variable' was not defined ")
# Out:
# Exception occurred(Name Error), because 'variable' was not defined

# %%
try:
    print(variable)
    
except NameError:
    print("Variable  is not defined")
    
except:
    print("An unknown error has occurred")
# Out:
# Variable  is not defined

# %% [markdown]
# #### <br><br>Example 2

# %%
f = open('nonexistent_file')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-03fb5d55533c> in <module>
# ----> 1 f = open('nonexistent_file')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistent_file'

# %%
try:
    f = open('nonexistent_file') 
    
except FileNotFoundError: 
    print('No such file')
    
except:
    print('An unknown error has occurred')
# Out:
# No such file

# %% [markdown]
# #### <br><br>Example 3
# Enter a string such as "python". This will throw a ValueError exception

# %%
input_var = int(input("Please enter a number:  "))
# Out:
# Please enter a number:  python
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-7ebda6fe1e7d> in <module>
# ----> 1 input_var = int(input("Please enter a number:  "))
#
# ValueError: invalid literal for int() with base 10: 'python'

# %% [markdown]
# #### Enter different strings and then a number
# This will keep throwing a ValueError until a number has been input.

# %%
while True:
    try:
        input_var = int(input("Please enter a number: "))
        break
    except ValueError:
        print("Oops!  That was not a valid number. Try again...")
# Out:
# Please enter a number: python
# Oops!  That was not a valid number. Try again...
# Please enter a number: cobra
# Oops!  That was not a valid number. Try again...
# Please enter a number: 37

# %% [markdown]
# #### It is up to you how you handle an exception
# Here, an exception is thrown the first two times a user enters a non-numeric value. Then on the third attempt we process the input as a string

# %%
attempts = 0

while True:
    
    try:
        input_var = input("Please enter a number: ")
        input_var = int(input_var)
        break
        
    except ValueError:
        attempts += 1
        
        if attempts < 3:
            print("Oops!  That was not a valid number. Try again...")
        else:
            print("You really want to input a string! Fine we'll handle it")
            input_var = str(input_var)
            break
# Out:
# Please enter a number: python
# Oops!  That was not a valid number. Try again...
# Please enter a number: cobra
# Oops!  That was not a valid number. Try again...
# Please enter a number: viper
# You really want to input a string! Fine we'll handle it

# %% [markdown]
# #### A KeyboardInterrupt can also be caught and handled
# Unless you'd rather wait for 111 seconds, hit the "Stop" button on the Jupyter Notebook to halt the sleep. That will trigger a keyboard interrupt and can be caught and handled

# %%
import time

time.sleep(111)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-24aead4d7aab> in <module>
#       1 import time
#       2
# ----> 3 time.sleep(111)
#
# KeyboardInterrupt:

# %%
try:
    time.sleep(111)
    
except KeyboardInterrupt:
    print ("KeyboardInterrupt has occurred!")
# Out:
# KeyboardInterrupt has occurred!

# %%
f = open('nonexistent_file')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-03fb5d55533c> in <module>
# ----> 1 f = open('nonexistent_file')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistent_file'

# %% [markdown]
# #### There is an exception hierarchy in Python
# FileNotFoundError is a subclass of OSError

# %%
try: 
    f = open('nonexistent_file') 
except OSError: 
        print('OS Error') 
except FileNotFoundError: 
        print('File not found Error')
# Out:
# OS Error

# %%
try: 
    f = open('nonexistent_file') 
except FileNotFoundError: 
        print('File not found Error') 
except OSError: 
        print('OS Error')
# Out:
# File not found Error

# %% [markdown]
# ## <br><br>`finally` block

# %% [markdown]
# ### The `finally` block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# #### <br><br>Example 1

# %%
print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2ea387ab95ff> in <module>
# ----> 1 print(var)
#
# NameError: name 'var' is not defined

# %%
try:
    print(var)
    
except NameError:
    print("The variable has not been defined")
    
finally:
    print("The 'try except block' ended")
# Out:
# The variable has not been defined
# The 'try except block' ended

# %%
var = 'xyz'

try:
    print(var)
    
except NameError:
    print("The variable has not been defined")
    
finally:
    print("The 'try except block' ended")
# Out:
# xyz
# The 'try except block' ended

# %% [markdown]
# #### <br><br>Example 2

# %%
try:
    file = open("testfile.txt", "w")
    
finally:
    print ("Done with processing the file.")
# Out:
# Done with processing the file.

# %%
ls
# Out:
# 1.FileOperationsTextFile.ipynb*   5.Exceptions .ipynb*
# 2.FileOperationsJSON.ipynb*       Demo6-PythonFromCommandLine_*
# 3.FileOperationsCSV.ipynb*        data_file/
# 4.FileOperationsHTMLFile  .ipynb* testfile.txt

# %%
file.closed
# Out:
# False

# %% [markdown]
# #### <br><br>Example 3

# %% [markdown]
# * Here using `try` and `finally`  we can open and close the file named `testfile.txt`

# %%
try:
    file = open("testfile.txt")
    
finally:
    file.close()
    print ("Done with processing the file.")
# Out:
# Done with processing the file.

# %%
file.closed
# Out:
# True

# %% [markdown]
# ## <br><br> `else`

# %% [markdown]
# ### We can use the `else` keyword to define a block of code to be executed if no errors were raised:

# %% [markdown]
# #### <br><br>Example 1

# %%
try:
    file = open("testfile.txt")
    file.write("Writing to the open file")
    
except:
    print("Oops! Something went wrong")
    
else:
    print("Nothing went wrong")
# Out:
# Oops! Something went wrong

# %%
try:
    file = open("testfile.txt", "w")
    file.write("Writing to the open file")
    print("One line written to the file")
    
except:
    print("Oops! Something went wrong")
    
else:
    print("Nothing went wrong")
# Out:
# One line written to the file
# Nothing went wrong

# %% [markdown]
# #### <br><br>Example 4

# %%
a = int(5)

b = str('Hello')

d = a + b + c

d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-107a7c54a784> in <module>
#       3 b = str('Hello')
#       4
# ----> 5 d = a + b + c
#       6
#       7 d
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #### Handle the TypeError

# %%
try: 
    
    a = int(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
# Out:
# TypeError was thrown

# %% [markdown]
# #### Fix the error
# This time a NameError is thrown and is not handled

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-1a061faa8c32> in <module>
#       3     a = str(5)
#       4     b = str('Hello')
# ----> 5     d = a + b + c
#       6
#       7 except TypeError:
#
# NameError: name 'c' is not defined

# %% [markdown]
# #### Handle the NameError

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print("NameError was thrown")
# Out:
# NameError was thrown

# %% [markdown]
# #### Fix the NameError
# A ValueError is thrown this time

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = int(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print('NameError was thrown')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-7ba832be9aa9> in <module>
#       3     a = str(5)
#       4     b = str('Hello')
# ----> 5     c = int(' World')
#       6     d = a + b + c
#       7
#
# ValueError: invalid literal for int() with base 10: ' World'

# %% [markdown]
# #### Handle the ValueError

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = int(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print('NameError was thrown')
    
except ValueError:
    print('ValueError was thrown')
# Out:
# ValueError was thrown

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = str(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print("NameError was thrown")
    
except ValueError:
    print('ValueError was thrown')    
    
except:
    print('An unknown error was thrown')

# %% [markdown]
# ## <br>Raising an Exception

# %% [markdown]
# #### Example1
# Define the conditions under which you would like to raise an exception

# %%
number = int(input("Enter a number:"))

if number > 5:
    raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))
# Out:
# Enter a number:34
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-34-d5abcb37332d> in <module>
#       2
#       3 if number > 5:
# ----> 4     raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))
#
# Exception: The number should not exceed 5. The value of number is: 34

# %% [markdown]
# #### Example 2
# Handle exceptions which you raise

# %%
number = int(input("Enter a number:"))

try:
    if number > 5:
        raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))

except Exception as error:
    print('Caught this Error: ' + repr(error))
# Out:
# Enter a number:36
# Caught this Error: Exception('The number should not exceed 5. The value of number is: 36')

# %% [markdown]
# # Exceptions

# %% [markdown]
# * An exception is an error that happens during execution of a program. When that
# error occurs, Python generate an exception that can be handled, which avoids your
# program to crash.<br><br>
# * Python has many built-in exceptions which forces your program to output an error when something in it goes wrong.<br><br>
# * When you think that you have a code which can produce an error then
# you can use exception handling.<br><br>

# %% [markdown]
# * The `try` block lets you test a block of code for errors.

# %% [markdown]
# * The `except` block lets you handle the error.

# %% [markdown]
# * The `finally` block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# ![Screenshot%202019-08-06%20at%206.51.33%20PM.png](attachment:Screenshot%202019-08-06%20at%206.51.33%20PM.png)
# ![Screenshot%202019-08-06%20at%206.52.18%20PM.png](attachment:Screenshot%202019-08-06%20at%206.52.18%20PM.png)

# %% [markdown]
# ## <br><br>Exception Handling

# %% [markdown]
# ## <br>`try` block

# %% [markdown]
# ### The `try` block lets you test a block of code for errors.

# %% [markdown]
# #### <br><br>Example 1

# %%
print(variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-503d059fc525> in <module>
# ----> 1 print(variable)
#
# NameError: name 'variable' is not defined

# %%
try:
    print(variable)
    
except:
    print("Exception occurred(Name Error), because 'variable' was not defined ")
# Out:
# Exception occurred(Name Error), because 'variable' was not defined

# %%
try:
    print(variable)
    
except NameError:
    print("Variable  is not defined")
    
except:
    print("An unknown error has occurred")
# Out:
# Variable  is not defined

# %% [markdown]
# #### <br><br>Example 2

# %%
f = open('nonexistent_file')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-03fb5d55533c> in <module>
# ----> 1 f = open('nonexistent_file')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistent_file'

# %%
try:
    f = open('nonexistent_file') 
    
except FileNotFoundError: 
    print('No such file')
    
except:
    print('An unknown error has occurred')
# Out:
# No such file

# %% [markdown]
# #### <br><br>Example 3
# Enter a string such as "python". This will throw a ValueError exception

# %%
input_var = int(input("Please enter a number:  "))
# Out:
# Please enter a number:  python
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-7ebda6fe1e7d> in <module>
# ----> 1 input_var = int(input("Please enter a number:  "))
#
# ValueError: invalid literal for int() with base 10: 'python'

# %% [markdown]
# #### Enter different strings and then a number
# This will keep throwing a ValueError until a number has been input.

# %%
while True:
    try:
        input_var = int(input("Please enter a number: "))
        break
    except ValueError:
        print("Oops!  That was not a valid number. Try again...")
# Out:
# Please enter a number: python
# Oops!  That was not a valid number. Try again...
# Please enter a number: cobra
# Oops!  That was not a valid number. Try again...
# Please enter a number: 37

# %% [markdown]
# #### It is up to you how you handle an exception
# Here, an exception is thrown the first two times a user enters a non-numeric value. Then on the third attempt we process the input as a string

# %%
attempts = 0

while True:
    
    try:
        input_var = input("Please enter a number: ")
        input_var = int(input_var)
        break
        
    except ValueError:
        attempts += 1
        
        if attempts < 3:
            print("Oops!  That was not a valid number. Try again...")
        else:
            print("You really want to input a string! Fine we'll handle it")
            input_var = str(input_var)
            break
# Out:
# Please enter a number: python
# Oops!  That was not a valid number. Try again...
# Please enter a number: cobra
# Oops!  That was not a valid number. Try again...
# Please enter a number: viper
# You really want to input a string! Fine we'll handle it

# %% [markdown]
# #### A KeyboardInterrupt can also be caught and handled
# Unless you'd rather wait for 111 seconds, hit the "Stop" button on the Jupyter Notebook to halt the sleep. That will trigger a keyboard interrupt and can be caught and handled

# %%
import time

time.sleep(111)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-24aead4d7aab> in <module>
#       1 import time
#       2
# ----> 3 time.sleep(111)
#
# KeyboardInterrupt:

# %%
try:
    time.sleep(111)
    
except KeyboardInterrupt:
    print ("KeyboardInterrupt has occurred!")
# Out:
# KeyboardInterrupt has occurred!

# %%
f = open('nonexistent_file')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-03fb5d55533c> in <module>
# ----> 1 f = open('nonexistent_file')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistent_file'

# %% [markdown]
# #### There is an exception hierarchy in Python
# FileNotFoundError is a subclass of OSError

# %%
try: 
    f = open('nonexistent_file') 
except OSError: 
        print('OS Error') 
except FileNotFoundError: 
        print('File not found Error')
# Out:
# OS Error

# %%
try: 
    f = open('nonexistent_file') 
except FileNotFoundError: 
        print('File not found Error') 
except OSError: 
        print('OS Error')
# Out:
# File not found Error

# %% [markdown]
# ## <br><br>`finally` block

# %% [markdown]
# ### The `finally` block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# #### <br><br>Example 1

# %%
print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2ea387ab95ff> in <module>
# ----> 1 print(var)
#
# NameError: name 'var' is not defined

# %%
try:
    print(var)
    
except NameError:
    print("The variable has not been defined")
    
finally:
    print("The 'try except block' ended")
# Out:
# The variable has not been defined
# The 'try except block' ended

# %%
var = 'xyz'

try:
    print(var)
    
except NameError:
    print("The variable has not been defined")
    
finally:
    print("The 'try except block' ended")
# Out:
# xyz
# The 'try except block' ended

# %% [markdown]
# #### <br><br>Example 2

# %%
try:
    file = open("testfile.txt", "w")
    
finally:
    print ("Done with processing the file.")
# Out:
# Done with processing the file.

# %%
ls
# Out:
# 1.FileOperationsTextFile.ipynb*   5.Exceptions .ipynb*
# 2.FileOperationsJSON.ipynb*       Demo6-PythonFromCommandLine_*
# 3.FileOperationsCSV.ipynb*        data_file/
# 4.FileOperationsHTMLFile  .ipynb* testfile.txt

# %%
file.closed
# Out:
# False

# %% [markdown]
# #### <br><br>Example 3

# %% [markdown]
# * Here using `try` and `finally`  we can open and close the file named `testfile.txt`

# %%
try:
    file = open("testfile.txt")
    
finally:
    file.close()
    print ("Done with processing the file.")
# Out:
# Done with processing the file.

# %%
file.closed
# Out:
# True

# %% [markdown]
# ## <br><br> `else`

# %% [markdown]
# ### We can use the `else` keyword to define a block of code to be executed if no errors were raised:

# %% [markdown]
# #### <br><br>Example 1

# %%
try:
    file = open("testfile.txt")
    file.write("Writing to the open file")
    
except:
    print("Oops! Something went wrong")
    
else:
    print("Nothing went wrong")
# Out:
# Oops! Something went wrong

# %%
try:
    file = open("testfile.txt", "w")
    file.write("Writing to the open file")
    print("One line written to the file")
    
except:
    print("Oops! Something went wrong")
    
else:
    print("Nothing went wrong")
# Out:
# One line written to the file
# Nothing went wrong

# %% [markdown]
# #### <br><br>Example 4

# %%
a = int(5)

b = str('Hello')

d = a + b + c

d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-107a7c54a784> in <module>
#       3 b = str('Hello')
#       4
# ----> 5 d = a + b + c
#       6
#       7 d
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #### Handle the TypeError

# %%
try: 
    
    a = int(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
# Out:
# TypeError was thrown

# %% [markdown]
# #### Fix the error
# This time a NameError is thrown and is not handled

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-1a061faa8c32> in <module>
#       3     a = str(5)
#       4     b = str('Hello')
# ----> 5     d = a + b + c
#       6
#       7 except TypeError:
#
# NameError: name 'c' is not defined

# %% [markdown]
# #### Handle the NameError

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print("NameError was thrown")
# Out:
# NameError was thrown

# %% [markdown]
# #### Fix the NameError
# A ValueError is thrown this time

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = int(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print('NameError was thrown')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-7ba832be9aa9> in <module>
#       3     a = str(5)
#       4     b = str('Hello')
# ----> 5     c = int(' World')
#       6     d = a + b + c
#       7
#
# ValueError: invalid literal for int() with base 10: ' World'

# %% [markdown]
# #### Handle the ValueError

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = int(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print('NameError was thrown')
    
except ValueError:
    print('ValueError was thrown')
# Out:
# ValueError was thrown

# %%
try: 
    
    a = str(5)
    b = str('Hello')
    c = str(' World')
    d = a + b + c
    
except TypeError:
    print ('TypeError was thrown')
    
except NameError:
    print("NameError was thrown")
    
except ValueError:
    print('ValueError was thrown')    
    
except:
    print('An unknown error was thrown')

# %% [markdown]
# ## <br>Raising an Exception

# %% [markdown]
# #### Example1
# Define the conditions under which you would like to raise an exception

# %%
number = int(input("Enter a number:"))

if number > 5:
    raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))
# Out:
# Enter a number:34
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-34-d5abcb37332d> in <module>
#       2
#       3 if number > 5:
# ----> 4     raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))
#
# Exception: The number should not exceed 5. The value of number is: 34

# %% [markdown]
# #### Example 2
# Handle exceptions which you raise

# %%
number = int(input("Enter a number:"))

try:
    if number > 5:
        raise Exception('The number should not exceed 5. The value of number is: {}'.format(number))

except Exception as error:
    print('Caught this Error: ' + repr(error))
# Out:
# Enter a number:36
# Caught this Error: Exception('The number should not exceed 5. The value of number is: 36')

# %%
num_list = [10,20,30,40,50]

# %%
def main():
    
    count = 0
    total = 0
    
    for i in num_list:
        count = count + 1
        total = total + i
        
        print("element is:", i)
        print("")
        print("sum :",total)
        print("")
    print("total sum:", total)

# %%
if __name__=="__main__":
    main()
# Out:
# element is: 10
#
# sum : 10
#
# element is: 20
#
# sum : 30
#
# element is: 30
#
# sum : 60
#
# element is: 40
#
# sum : 100
#
# element is: 50
#
# sum : 150
#
# total sum: 150
